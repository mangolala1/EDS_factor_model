# %%
import pandas as pd
import numpy as np

# %%
b = pd.read_parquet('C:/Users/caiho/Desktop/EDS_factor_model/data/market_value.parquet')
b
# Out:
#          FACTSET_ID       DATE CURRENCY     MARKETCAP
# 0          DYJJZ3-R 2020-01-01      USD    571.448519
# 1          BS9ZK4-R 2020-01-01      USD  26440.666487
# 2          NYKB2Q-R 2020-01-01      JPY   5519.184691
# 3          LRG9XL-R 2020-01-01      JOD     10.150000
# 4          JMD5NG-R 2020-01-01      CNY   3496.720107
# ...             ...        ...      ...           ...
# 79181990   GZGJTY-R 2025-12-12      USD    335.399995
# 79181991   JCNM95-R 2025-12-12      USD   4384.876913
# 79181992   CW9B38-R 2025-12-12      CNY   9192.322998
# 79181993   BQT8YS-R 2025-12-12      INR  18054.157720
# 79181994   XRB5RR-R 2025-12-12      SAR   7198.764919
#
# [79181995 rows x 4 columns]

# %%
pd.read_parquet('C:/Users/caiho/Desktop/EDS_factor_model/data/enterprise_value.parquet')
# Out:
#           FACTSET_ID       DATE  ENTERPRISE_VALUE EV_COMPONENTS_DATE
# 0           B00044-R 2020-01-01      82742.722939               None
# 1           VG0PKZ-R 2020-01-01         30.691572         2019-12-31
# 2           H0BHCC-R 2020-01-01      17255.190582               None
# 3           WSYYG7-R 2020-01-01       6623.675230         2019-12-31
# 4           X479N0-R 2020-01-01        695.156054         2019-12-31
# ...              ...        ...               ...                ...
# 253816461   TD28HD-R 2025-12-11         57.580968         2025-09-30
# 253816462   GZBZL4-R 2025-12-11      85023.034573         2025-09-30
# 253816463   GZC0CX-R 2025-12-11       1034.020354         2025-09-30
# 253816464   TD2BMG-R 2025-12-11       4436.675129         2008-12-31
# 253816465   XRB643-R 2025-12-11         14.073463         2025-06-30
#
# [253816466 rows x 4 columns]

# %%
df = pd.read_parquet('C:/Users/caiho/Desktop/EDS_factor_model/data/fundamentals.parquet')
df
# Out:
#           FACTSET_ID        DATE     SALES_LTM    SALES_NTM  COGS_LTM  \
# 0           B007G7-R  2019-01-01           NaN          NaN       NaN
# 1           B007LC-R  2019-01-01           NaN          NaN       NaN
# 2           B00DXJ-R  2019-01-01           NaN          NaN       NaN
# 3           B00FG1-R  2019-01-01    274.874480    294.23758       NaN
# 4           B00M5L-R  2019-01-01           NaN          NaN       NaN
# ...              ...         ...           ...          ...       ...
# 134132505   XR7GZL-R  2025-11-13           NaN          NaN       NaN
# 134132506   XR82VW-R  2025-11-13           NaN          NaN       NaN
# 134132507   XR8586-R  2025-11-13  25356.200000  28105.40000       NaN
# 134132508   XR8872-R  2025-11-13      0.972358     11.96410       NaN
# 134132509   XR9F0R-R  2025-11-13           NaN          NaN       NaN
#
#               COGS_NTM  EBITDA_LTM  EBITDA_NTM     EPS_LTM     EPS_NTM
# ...

# %%
np.sort(df["DATE"].unique())
# Out:
# array([datetime.date(2019, 1, 1), datetime.date(2019, 1, 2),
#        datetime.date(2019, 1, 3), ..., datetime.date(2025, 11, 11),
#        datetime.date(2025, 11, 12), datetime.date(2025, 11, 13)],
#       shape=(1793,), dtype=object)

# %%
df.dropna()
# Out:
#           FACTSET_ID        DATE     SALES_LTM    SALES_NTM      COGS_LTM  \
# 9           B018KB-R  2019-01-01     843.30927     919.3478     688.65204
# 11          B01HWF-R  2019-01-01    1843.53080    1977.6931    1484.83300
# 28          B02ZTY-R  2019-01-01  119685.11000  137786.4000  106707.54000
# 31          B03872-R  2019-01-01   34663.48000   39548.2660    4127.23000
# 33          B03BC4-R  2019-01-01   10691.99800   12248.4150    5537.69870
# ...              ...         ...           ...          ...           ...
# 134132488   XQPQNH-R  2025-11-13   17794.10000   18862.1000   15970.10000
# 134132491   XQRMDD-R  2025-11-13   14871.40000   17236.2000    9709.21000
# 134132493   XQVGNX-R  2025-11-13     188.94500     559.7230      75.21200
# 134132500   XR06QC-R  2025-11-13      16.30810      23.9549       7.01063
# 134132501   XR0GGW-R  2025-11-13    1012.12000    1140.3100     286.15900
#
#                COGS_NTM   EBITDA_LTM    EBITDA_NTM    EPS_LTM    EPS_NTM
# ...
